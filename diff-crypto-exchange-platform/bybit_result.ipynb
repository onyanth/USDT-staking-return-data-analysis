# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import re

# %%
import os
os.chdir("C:\\Users\\User\\Desktop\\data_sciencebootcamp\\Course Materials-20220421T131209Z-001\\Course Materials\\01Foundation\\13-web_scraping")

# %%
URL = "https://www.bybit.com/en-US/earn/flexible-staking"
driver = webdriver.Chrome('./chromedriver')
driver.get(URL)
subhtml = driver.page_source

'''
tag_day = driver.find_element_by_xpath('where is the %')
where is the xpath (address) => you find out the object and click the "..." at the left and choose copy > copy xpath
elelink_day = driver.find_element_by_xpath('where is the hyperlink')
'''

all_data = []

tag_fl = driver.find_element_by_xpath('//*[@id="flexible-panel"]/section[3]/div[2]/div[3]/div/div[3]')
print(tag_fl.text)
all_data.insert(0,tag_fl.text)
print(all_data)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_13964/3841427301.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# 3.00%  APY
# ['3.00%  APY']
# C:\Users\User\AppData\Local\Temp/ipykernel_13964/3841427301.py:8: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   tag_fl = driver.find_element_by_xpath('//*[@id="flexible-panel"]/section[3]/div[2]/div[3]/div/div[3]')

# %%
import re
t_all_data = ['3.00%  APY']
r_all_data = []
percentage = r'\d*.?\d*'  # take the number near the decimal point
for i in range(0,len(all_data)):
    data = re.findall(percentage,all_data[i])
    r_all_data.append(data[0])
    r_all_data[i] = float(r_all_data[i])
print(r_all_data)
# Out:
# [3.0]

# %%
Bybit = [r_all_data[0], r_all_data[0],r_all_data[0],r_all_data[0],r_all_data[0],r_all_data[0],r_all_data[0]]
print(Bybit)
# Out:
# [3.0, 3.0, 3.0, 3.0, 3.0, 3.0, 3.0]
